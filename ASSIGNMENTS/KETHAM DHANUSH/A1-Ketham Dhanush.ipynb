# %%
import numpy as np
import pandas as pd
#generatung random values
d = np.random.rand(4, 4)
# Creating a DataFrame
df = pd.DataFrame(d, columns=['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4'], index =['Observation 1','Observation 2','Observation 3','Observation 4'])
# Print the DataFrame
print(df)
# Out:
#                Feature 1  Feature 2  Feature 3  Feature 4
# Observation 1   0.533923   0.079247   0.702004   0.945869
# Observation 2   0.792854   0.782719   0.835878   0.175138
# Observation 3   0.633165   0.971243   0.590536   0.225798
# Observation 4   0.906264   0.646328   0.845418   0.166774

# %%
import numpy as np
import pandas as pd
#Renaming Columns
df = df.rename(columns = {'Feature 1' : 'Random Value 1',
 'Feature 2' : 'Random Value 2',
'Feature 3' : 'Random Value 3',
'Feature 4' : 'Random Value 4'})
# Print the DataFrame
print(df)
# Out:
#                Random Value 1  Random Value 2  Random Value 3  Random Value 4
# Observation 1        0.533923        0.079247        0.702004        0.945869
# Observation 2        0.792854        0.782719        0.835878        0.175138
# Observation 3        0.633165        0.971243        0.590536        0.225798
# Observation 4        0.906264        0.646328        0.845418        0.166774

# %%
import numpy as np
import pandas as pd
#To describe the Statistical Description
stat = df.describe()
# Print the DataFrame
print(df)
print('\n')
print(stat)
# Out:
#                Random Value 1  Random Value 2  Random Value 3  Random Value 4
# Observation 1        0.533923        0.079247        0.702004        0.945869
# Observation 2        0.792854        0.782719        0.835878        0.175138
# Observation 3        0.633165        0.971243        0.590536        0.225798
# Observation 4        0.906264        0.646328        0.845418        0.166774
#
#
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.716551        0.619884        0.743459        0.378395
# std          0.165448        0.384255        0.121162        0.379214
# min          0.533923        0.079247        0.590536        0.166774
# 25%          0.608354        0.504558        0.674137        0.173047
# 50%          0.713009        0.714523        0.768941        0.200468
# 75%          0.821207        0.829850        0.838263        0.405816
# max          0.906264        0.971243        0.845418        0.945869

# %%
import numpy as np
import pandas as pd
#Checking NULL values
null_val = df.isnull().sum()
#Checking the Data types
data_type = df.dtypes
# Print the DataFrame
print(null_val)
print('\n')
print(data_type)
# Out:
# Random Value 1    0
# Random Value 2    0
# Random Value 3    0
# Random Value 4    0
# dtype: int64
#
#
# Random Value 1    float64
# Random Value 2    float64
# Random Value 3    float64
# Random Value 4    float64
# dtype: object

# %%
import numpy as np
import pandas as pd
# Display columns using the location method
location_method = df[['Random Value 2', 'Random Value 3']]
print("Columns using location method:")
print(location_method)
# Display columns using the index location method
index_location_method = df.iloc[:, 1:3]
print("\nColumns using index location method :")
print(index_location_method)
# Out:
# Columns using location method:
#                Random Value 2  Random Value 3
# Observation 1        0.079247        0.702004
# Observation 2        0.782719        0.835878
# Observation 3        0.971243        0.590536
# Observation 4        0.646328        0.845418
#
# Columns using index location method :
#                Random Value 2  Random Value 3
# Observation 1        0.079247        0.702004
# Observation 2        0.782719        0.835878
# Observation 3        0.971243        0.590536
# Observation 4        0.646328        0.845418
